# %% [markdown]
# <a href="https://colab.research.google.com/github/pkrodev/OpenCV_tutorial/blob/main/ep8/Open_cv_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
img1 = cv2.imread('assets/pic.jpg')

# %%
img2 = cv2.imread('assets/pic.jpg', 0)

# %%
face=cv2.imread('assets/face1.JPG')
face.shape
# Out:
# (73, 65, 3)

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=998x612>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=998x612>

# %%
max_width, max_height=img2.shape

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

# %%
faces = face_cascade.detectMultiScale(img2, scaleFactor=1.05, minNeighbors=5, maxSize=(70,65))
img1 = cv2.imread('assets/pic.jpg')
for (x, y, w, h) in faces:
    cv2.rectangle(img1, (x, y), (x + w, y + h), (255, 0, 0), 5)
    roi_gray = img2[y:y+w, x:x+w]
    roi_color = img1[y:y+h, x:x+w]

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=998x612>
