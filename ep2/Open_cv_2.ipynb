# %% [markdown]
# <a href="https://colab.research.google.com/github/pkrodev/OpenCV_tutorial/blob/main/ep2/Open_cv_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('assets/pic.jpg', -1)

# %%
print(img)

# %%
print(img.shape) #612-heigh 998-width 3 -channels (blue green red)
# Out:
# (612, 998, 3)

# %%
print(img[257][200:400])

# %%
for i in range(300):
  for j in range(img.shape[1]):
    img[i][j]=[255,255,255]

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=998x612>

# %%
img = cv2.imread('assets/pic.jpg', -1)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=998x612>

# %%
img = cv2.imread('assets/pic.jpg', -1)

# %%
copy=img[100:250, 0:998]
img[0:150, 0:998]=copy
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=998x612>
